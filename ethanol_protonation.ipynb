# %% [markdown]
# # 4HFI H235 Investigation

# %%
from __future__ import print_function
# %matplotlib inline
import mdtraj as md
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy
from scipy.spatial.distance import squareform
import pandas as pd
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')
import MDAnalysis as mda
from statistics import mode
import ast
import msmexplorer as msme
from msmbuilder.utils import load,dump
import itertools
from msmbuilder.featurizer import ContactFeaturizer
from msmbuilder.featurizer import DihedralFeaturizer
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
#XRD Ensemble
#28 4NPQ
#18 4HFI

# %%
md_data_235 = pd.read_pickle('masterthesis/glic_activation_open_235.pickle')

# %%
for feature in md_data_235.columns[11:]:
    fig, ax = plt.subplots(figsize=(15, 3))
    fig.suptitle('4HFI_' + feature)
    group = md_data_235.groupby(['system'],sort=False)[feature]
    mean = group.mean()
    errors = group.sem()
    mean.plot.bar(yerr=errors,ax=ax)
    ax.set_xticklabels(['WT_1H','WT_2H','F_1H','F_2H','I_1H','I_2H','FI_1H','FI_2H'])

# %% [markdown]
# # Ethanol Investigationm

# %% [markdown]
# ## Per intersubunit site for intersubunit/intrasubunit ethanol

# %%
md_data_ethanol = pd.read_pickle('pdc/ethanol/glic_subunit_ethanol.pickle')

# %%
for feature in md_data_ethanol.columns[11:-1]:
    fig, ax = plt.subplots(figsize=(15, 3))
    fig.suptitle('4HFI_' + feature)
    group = md_data_ethanol[(md_data_ethanol.traj_time > 30) & (md_data_ethanol.system.isin(['0','1','3','4','9','10','11','12']))].groupby(['system'],sort=False)[feature]
    mean = group.mean()
    errors = group.sem()
    mean.plot.bar(yerr=errors,ax=ax)
    ax.set_xticklabels(['open_WT_46','open_F238L_46','open_I233T_46','open_FI_46','close_WT_70','close_F238L_70','close_I233T_70','close_FI_70'])

# %% [markdown]
# Systems:
# - 0              '4HFI_pH46_ethanol_md1',
# - 1               '4HFI_F238L_pH46_ethanol_md4'
# - 2              '4HFI_F238L_pH46_ethanol_md1',
# - 3             '4HFI_I233T_pH46_ethanol_md1',
# - 4                '4HFI_F238LI233T_pH46_ethanol_md1',
# - 5             '4HFI_pH70_ethanol_md1',
# - 6              '4HFI_F238L_pH70_ethanol_md1',
# - 7              '4HFI_I233T_pH70_ethanol_md1',
# - 8               '4HFI_F238LI233T_pH70_ethanol_md1',
# - 9               '4NPQ_pH70_ethanol_md1',
# - 10              '4NPQ_F238L_pH70_ethanol_md1',
# - 11               '4NPQ_I233T_pH70_ethanol_md1',
# - 12                '4NPQ_F238LI233T_pH70_ethanol_md1']

# %%
for feature in md_data_ethanol.columns[11:-1]:
    fig, ax = plt.subplots(figsize=(15, 3))
    fig.suptitle('4HFI_' + feature)
    group = md_data_ethanol[(md_data_ethanol.traj_time > 30)].groupby(['system'],sort=False)[feature]
    mean = group.mean()
    errors = group.sem()
    mean.plot.bar(yerr=errors,ax=ax)
#    ax.set_xticklabels(['open_WT_46','open_F238L_46','open_I233T_46','open_FI_46','close_WT_70','close_F238L_70','close_I233T_70','close_FI_70'])
