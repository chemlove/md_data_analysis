# %% [markdown]
# # RMSD Plotting under Pandas Dataframe

# %% [markdown]
# Close-close MD simulation

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib
# %matplotlib inline

# %% [markdown]
# ## Ref: First frame of each MD ensemble (CA, 1555 atoms)

# %% [markdown]
# ### 4NPQ_BA1 WT

# %%
Location_4NPQ_BA1 = '/media/scottzhuang/data/MD/BA1/4NPQ_BA1_md.skip10.ca.rmsd.log'
rmsd_4NPQ_BA1 = pd.read_table(Location_4NPQ_BA1,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238L

# %%
Location_4NPQ_BA1_F238L = '/media/scottzhuang/data/MD/4NPQ_F238L/4NPQ_BA1_F238L_md.skip10.ca.rmsd.log'
rmsd_4NPQ_BA1_F238L = pd.read_table(Location_4NPQ_BA1_F238L,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 I233T

# %%
Location_4NPQ_BA1_I233T = '/media/scottzhuang/data/MD/4NPQ_BA1_I233T_MD/4NPQ_BA1_I233T_md.skip10.ca.rmsd.log'
rmsd_4NPQ_BA1_I233T = pd.read_table(Location_4NPQ_BA1_I233T,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238L I233T

# %%
Location_F238LI233T = '/media/scottzhuang/data/MD/F238LI233T/4NPQ_BA1_F238LI233T_md.skip10.ca.rmsd.log'
rmsd_F238LI233T = pd.read_table(Location_F238LI233T,sep=" ",nrows=2700)

# %% [markdown]
# ### Ensemble

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1.plot(x='Frame', y='RMSD', ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L.plot(x='Frame', y='RMSD', ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T.plot(x='Frame', y='RMSD', ax=axes[1,0],legend=False,title="I233T")
rmsd_F238LI233T.plot(x='Frame', y='RMSD', ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1.plot.hist(x='Frame',bins=100,ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L.plot.hist(x='Frame',bins=100,ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T.plot.hist(x='Frame',bins=100,ax=axes[1,0],legend=False,title="I233T")
rmsd_F238LI233T.plot.hist(x='Frame',bins=100,ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_F238LI233T.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("First frame of each MD ensemble (CA, 1555 atoms)")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)
rmsd_F238LI233T.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("First frame of each MD ensemble (CA, 1555 atoms)")

# %% [markdown]
# ## Ref: First frame of 4NPQ_md (CA, 1555 atoms)

# %% [markdown]
# ### 4NPQ_BA1 WT

# %%
Location_4NPQ_BA1_md_skip10_ca_ref_4NPQmd = '/media/scottzhuang/data/MD/BA1/4NPQ_BA1_md.skip10.ca.ref_4NPQmd_rmsd.log'
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd = pd.read_table(Location_4NPQ_BA1_md_skip10_ca_ref_4NPQmd,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238L

# %%
Location_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd = '/media/scottzhuang/data/MD/4NPQ_F238L/4NPQ_BA1_F238L_md.skip10.ca.ref_4NPQmd_rmsd.log'
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd = pd.read_table(Location_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 I233T

# %%
Location_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd = '/media/scottzhuang/data/MD/4NPQ_BA1_I233T_MD/4NPQ_BA1_md.skip10.ca.ref_4NPQmd_rmsd.log'
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd = pd.read_table(Location_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238LI233T

# %%
Location_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd = '/media/scottzhuang/data/MD/F238LI233T/4NPQ_BA1_F238LI233T_md.skip10.ca.ref_4NPQmd_rmsd.log'
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd = pd.read_table(Location_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd,sep=" ",nrows=2700)

# %% [markdown]
# ### Ensemble

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes[1,0],legend=False,title="I233T")
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes[1,0],legend=False,title="I233T")
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("First frame of 4NPQ_md (CA, 1555 atoms)")
axes.set_ylim(1,6)
# Out:
# (1, 6)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("First frame of 4NPQ_md (CA, 1555 atoms)")
axes.set_xlim(1)
# Out:
# (1, 4.5)

# %% [markdown]
# ## Ref: 4NPQ_BA1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)

# %% [markdown]
# ### 4NPQ_BA1 WT

# %%
Location_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb = '/media/scottzhuang/data/MD/BA1/4NPQ_BA1_md.skip10.ca.ref_4NPQpdb_rmsd.log'
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb = pd.read_table(Location_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238L

# %%
Location_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb = '/media/scottzhuang/data/MD/4NPQ_F238L/4NPQ_BA1_F238L_md.skip10.ca.ref_4NPQpdb_rmsd.log'
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb = pd.read_table(Location_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 I233T

# %%
Location_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb = '/media/scottzhuang/data/MD/4NPQ_BA1_I233T_MD/4NPQ_BA1_I233T_md.skip10.ca.ref_4NPQpdb_rmsd.log'
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb = pd.read_table(Location_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238LI233T

# %%
Location_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb = '/media/scottzhuang/data/MD/F238LI233T/4NPQ_BA1_F238LI233T_md.skip10.ca.ref_4NPQpdb_rmsd.log'
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb = pd.read_table(Location_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### Ensemble

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes[1,0],legend=False,title="I233T")
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes[1,0],legend=False,title="I233T")
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("4NPQ_BA1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)")
axes.set_ylim(1,6)
# Out:
# (1, 6)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("4NPQ_BA1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)")
axes.set_xlim(1)
# Out:
# (1, 4.5)

# %% [markdown]
# ## Ref: 4HFI_1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)

# %% [markdown]
# ### 4NPQ_BA1 WT

# %%
Location_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb = '/media/scottzhuang/data/MD/BA1/4NPQ_BA1_md.skip10.ca.ref_4HFIpdb_rmsd.log'
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb = pd.read_table(Location_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238L

# %%
Location_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb = '/media/scottzhuang/data/MD/4NPQ_F238L/4NPQ_BA1_F238L_md.skip10.ca.ref_4HFIpdb_rmsd.log'
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb = pd.read_table(Location_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 I233T

# %%
Location_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb = '/media/scottzhuang/data/MD/4NPQ_BA1_I233T_MD/4NPQ_BA1_I233T_md.skip10.ca.ref_4HFIpdb_rmsd.log'
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb = pd.read_table(Location_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### 4NPQ_BA1 F238LI233T

# %%
Location_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb = '/media/scottzhuang/data/MD/F238LI233T/4NPQ_BA1_F238LI233T_md.skip10.ca.ref_4HFIpdb_rmsd.log'
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb = pd.read_table(Location_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb,sep=" ",nrows=2700)

# %% [markdown]
# ### Ensemble

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes[1,0],legend=False,title="I233T")
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes[0,0],legend=False,title="WT")
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes[0,1],legend=False,title="F238L")
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes[1,0],legend=False,title="I233T")
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes[1,1],legend=False,title="F238LI233T")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("4HFI_1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)")
axes.set_ylim(2,6.5)
# Out:
# (2, 6.5)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("4HFI_1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)")
axes.set_xlim(2)
# Out:
# (2, 5.0)

# %% [markdown]
# ## Some comparisons

# %% [markdown]
# ### Ref as md first frame vs XRD of 4NPQ

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("First frame of 4NPQ_md (CA, 1555 atoms)")
axes.set_ylim(1,6)
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("4NPQ_BA1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)")
axes.set_ylim(1,6)
# Out:
# (1, 6)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("First frame of 4NPQ_md (CA, 1555 atoms)")
axes.set_xlim(1)
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['WT', 'F238L','I233T','I233TF238L'])
fig.suptitle("4NPQ_BA1 (from XRD ensemble, pdb file, CA, 1540 atoms!!!)")
axes.set_xlim(1)
# Out:
# (1, 4.5)

# %% [markdown]
# ### 4NPQ_BA with different ref plot

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("4NPQ_BA1")
axes.set_ylim(1,6)
#4NPQmd, 4NPQpdb and own_first_frame overlap
# Out:
# (1, 6)

# %% [markdown]
# ### 4NPQ_BA_F238L with different ref plot

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("4NPQ_BA1_F238L")
axes.set_ylim(1,6)
#4NPQmd and 4HFIpdb overlap
#4NPQpdb and own first frame overlap
# Out:
# (1, 6)

# %% [markdown]
# ### 4NPQ_BA_I233T with different ref plot

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("4NPQ_BA1_I233T")
axes.set_ylim(1,6)
#4NPQmd and #4NPQ pdb overlap
# Out:
# (1, 6)

# %% [markdown]
# ### 4NPQ_BA_F238LI233T with different ref plot

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb.plot(x='frame', y='RMSD', ax=axes,alpha=0.7)
rmsd_F238LI233T.plot(x='Frame', y='RMSD', ax=axes,alpha=0.7)
axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("4NPQ_BA1_F238LI233T")
axes.set_ylim(1,6)
#4HFIpdb and own first frame overlap
#4NPQpdb and 4NPQmd overlap
# Out:
# (1, 6)

# %% [markdown]
# ### 4NPQ_BA with different ref histogram

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)

axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("BA1")
axes.set_xlim(1)
axes.set_xlim(1)
# Out:
# (1, 3.5)

# %% [markdown]
# ### 4NPQ_BA_F238L with different ref histogram

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238L.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)

axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("F238L")
axes.set_xlim(1)
axes.set_xlim(1)
# Out:
# (1, 5.0)

# %% [markdown]
# ### 4NPQ_BA_I233T with different ref histogram

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_I233T.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)

axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("I233T")
axes.set_xlim(1)
axes.set_xlim(1)
# Out:
# (1, 4.5)

# %% [markdown]
# ### 4NPQ_BA_F238LI233T with different ref histogram

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQmd.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4NPQpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_4NPQ_BA1_F238LI233T_md_skip10_ca_ref_4HFIpdb.plot.hist(x='frame',bins=100,ax=axes,alpha=0.7)
rmsd_F238LI233T.plot.hist(x='Frame',bins=100,ax=axes,alpha=0.7)
axes.legend(['ref:4NPQmd','ref:4NPQpdb','ref:4HFIpdb','ref:own_first_frame'])
fig.suptitle("F238LI233T")
axes.set_xlim(1)
axes.set_xlim(1)
# Out:
# (1, 5.0)
